# %% [markdown]
# ## Lab 3: pandas
#
# #### Introduction
#
# We will examine a dataset containing characteristics of lego sets manufactured between 1961 and 2019 from the BRICKSET website. Variables in the dataset are described below.
#
# | VARIABLE             |      DESCRIPTION             |
# |:----------|:-------------|
# | ID |  set id |
# | Name |    name of set   |
# | Themegroup | themegroup of set |
# | Theme |  theme of set |
# | Subtheme |    subtheme of set   |
# | Year | year released |
# | Pieces |  number of pieces |
# | Minifig |    number of minifigs   |
# | Package | type of packaging |
# | Retail_Price |  recommended retail pri
#
#
#
# Load pandas to read in the data and save it as dataframe named lego.

# %%
import pandas as pd

lego = pd.read_csv('lego.csv')
lego.sample(15)
# Out:
#               id                            name     themegroup  \
# 4906     20017-1  BrickMaster - Prince of Persia       Licensed
# 11265      313-2            Bracelet and Pendant          Girls
# 12134      223-2              1 x 1 Round Bricks          Basic
# 2084     76047-1           Black Panther Pursuit       Licensed
# 114      42096-1                 Porsche 911 RSR      Technical
# 7589      4450-1                   Mid Fielder 2     Modern day
# 10559      527-1              Basic Building Set          Basic
# 5807      7737-1   Coast Guard 4WD & Jet Scooter     Modern day
# 3081   5004251-1   LEGO Friends Olivia Key Light  Miscellaneous
# 3313     79018-1             The Lonely Mountain       Licensed
# 6420      8730-1                      Toa Hewkii   Construction
# 10174     6673-1                    Solo Trainer     Modern day
# 6772    LMG010-1                           Santa  Miscellaneous
# 4214     79000-1            Riddles for the Ring       Licensed
# 6038      7029-1            Skeleton Ship Attack     Historical
#
#                      theme                       subtheme    year  pieces  \
# 4906      Prince of Persia                            NaN  2010.0    52.0
# 11265                Scala                      Jewellery  1979.0   137.0
# 12134               System                   Supplemental  1958.0     NaN
# 2084   Marvel Super Heroes     Captain America: Civil War  2016.0   287.0
# 114                Technic                            NaN  2019.0  1580.0
# 7589                Sports                       Football  2002.0     4.0
# 10559                Basic                            NaN  1987.0   192.0
# 5807                  City                    Coast Guard  2008.0   130.0
# 3081                  Gear                         Lights  2014.0     NaN
# 3313            The Hobbit  The Battle of the Five Armies  2014.0   866.0
# 6420              Bionicle                      Toa Inika  2006.0    62.0
# 10174                 Town                         Flight  1990.0    74.0
# 6772           Promotional                  Miscellaneous  2005.0    13.0
# 4214            The Hobbit          An Unexpected Journey  2012.0   105.0
# 6038                Castle                    Fantasy Era  2007.0   628.0
#
#        minifigs             package  retail_price
# 4906          1             Polybag           NaN
# 11265         0                 NaN           NaN
# 12134         0                 Box           NaN
# 2084          3                 Box         29.99
# 114           0                 Box        149.99
# 7589          1             Polybag           NaN
# 10559         1                 NaN           NaN
# 5807          1                 Box          9.99
# 3081          0                 NaN         12.99
# 3313          5                 Box        129.99
# 6420          0                 NaN          9.99
# 10174         1                 Box          8.00
# 6772          0  None (loose parts)           NaN
# 4214          2                 Box          9.99
# 6038          7                 Box         69.99

# %%
# Exploring the data:
lego.shape  # it has 10 col & 12214 rows

# %%
lego.describe()  # only shows numerical columns
# count we can see that not all info is available,
# for example we can see that only 7849 observations have a retail price.

# %%
lego.theme.unique()
# Out:
# array(['Promotional', 'Creator Expert', 'Toy Story', 'Duplo', 'Classic',
#        'Education', 'Architecture', 'Minecraft', 'Ideas',
#        'The Lego Movie 2: The Second Part', 'City', 'Friends',
#        'Marvel Super Heroes', 'Ninjago', 'Creator', 'Seasonal', 'Xtra',
#        'BrickHeadz', 'Miscellaneous', 'Disney', 'Technic', 'Gear',
#        'Collectable Minifigures', 'Star Wars', 'Speed Champions',
#        'Jurassic World', 'Overwatch', 'DC Comics Super Heroes', 'FORMA',
#        'Powered Up', 'Juniors', 'Unikitty', 'Wizarding World',
#        'The LEGO Batman Movie', 'Elves', 'The Powerpuff Girls', 'Explore',
#        'The LEGO Ninjago Movie', 'Nexo Knights', 'Harry Potter', 'Boost',
#        'DC Super Hero Girls', 'CITY', 'Pirates of the Caribbean',
#        'Dimensions', 'Books', 'Scooby-Doo', 'Mixels', 'Mindstorms',
#        'Bionicle', 'Castle', 'The Angry Birds Movie', 'Ghostbusters', nan,
#        'Space', 'Legends of Chima', 'Pirates', 'Serious Play',
#        'Ultra Agents', 'The LEGO Movie', 'The Simpsons',
#        'Bricks and More', 'Fusion', 'Teenage Mutant Ninja Turtles',
#        'HERO Factory', 'The Hobbit', 'The Lord of the Rings',
#        'Master Builder Academy', 'The Lone Ranger', 'Games',
#        'Power Functions', 'Monster Fighters', 'Life of George', 'Racers',
#        'SpongeBob SquarePants', 'Make and Create', 'Dino', 'Cars',
#        "Pharaoh's Quest", 'Atlantis', 'Prince of Persia', 'Primo',
#        'World Racers', 'Power Miners', 'Ben 10: Alien Force',
#        'Indiana Jones', 'Agents', 'Factory', 'Belville', 'Batman',
#        'Exo-Force', 'Sports', 'Aqua Raiders', 'Trains',
#        'Avatar The Last Airbender', 'World City', 'Quatro', 'Vikings',
#        'Clikits', 'Bulk Bricks', 'Spider-Man', 'Dino 2010', 'Dino Attack',
#        'Model Team', 'Town', 'Alpha Team', '4 Juniors', 'Hobby Set',
#        'Discovery', 'Adventurers', 'Island Xtreme Stunts', 'Basic',
#        'Studios', 'Jack Stone', 'Spybotics', 'Galidor', 'Western',
#        'Dacta', 'Action Wheelers', 'Scala', 'Dinosaurs', 'Rock Raiders',
#        'Mickey Mouse', 'Service Packs', 'Aquazone', 'Znap', 'Freestyle',
#        'Time Cruisers', 'Boats', 'Assorted', 'Fabuland',
#        'Universal Building Set', 'Homemaker', 'Samsonite', 'PreSchool',
#        'LEGOLAND', 'Building Set with People', 'Minitalia', 'System',
#        'Legoland'], dtype=object)

# %%
lego.theme.value_counts()
# Out:
# theme
# Duplo                        1050
# Town                          640
# Star Wars                     631
# Gear                          585
# Collectable Minifigures       565
#                              ...
# Avatar The Last Airbender       2
# Primo                           2
# The Simpsons                    2
# Boost                           1
# CITY                            1
# Name: count, Length: 139, dtype: int64

# %% [markdown]
# #### Question 1:
# Some sets have missing information for retail_price or pieces or both. This could be because the sets are free (giveaways), they aren’t traditional lego sets (comic books, etc) or just because the information is missing. Filter the lego dataset based on the specifications below and save the result as lego. Hence, you will overwrite the original lego object. In addition, describe the implications of removing these sets.
#
# Your new lego (data frame) should have:
#
# • no missing pieces
#
# • only contain sets with a nonzero number of pieces
#
# • no missing retail_price
#
# • only contain sets with a nonzero retail_price
#
# • no missing year
#
# - Print out the shape of the dataframe after cleaning the dataset.
# -

# %%
# Write your answer here
lego2 = lego.dropna()  # drops all observations w missing values
lego2
# Out:
#             id                                         name      themegroup  \
# 1      10264-1                                Corner Garage    Model making
# 2      10265-1                                 Ford Mustang    Model making
# 3      10766-1                                   Woody & RC        Licensed
# 4      10769-1                                  RV Vacation        Licensed
# 5      10770-1               Buzz & Woody's Carnival Mania!        Licensed
# ...        ...                                          ...             ...
# 12082    805-2                             3 Little Indians  Vintage themes
# 12083    806-2                                Cowboy & Pony  Vintage themes
# 12091    520-4  2 X 2 Plate (Flat Roof Bricks with 4 Studs)  Vintage themes
# 12092   7100-1              Samsonite Large Educational Set  Vintage themes
# 12106    215-3                                 2 X 8 Bricks  Vintage themes
#
#                 theme           subtheme    year  pieces  minifigs  \
# 1      Creator Expert  Modular Buildings  2019.0  2569.0         6
# 2      Creator Expert           Vehicles  2019.0  1471.0         0
# 3           Toy Story        Toy Story 4  2019.0    69.0         0
# 4           Toy Story        Toy Story 4  2019.0   178.0         0
# 5           Toy Story        Toy Story 4  2019.0   230.0         0
# ...               ...                ...     ...     ...       ...
# 12082       Samsonite        Model Maker  1964.0    89.0         0
# 12083       Samsonite        Model Maker  1964.0    87.0         0
# 12091       Samsonite       Supplemental  1961.0    40.0         0
# 12092       Samsonite        Educational  1963.0  3250.0         0
# 12106       Samsonite       Supplemental  1961.0     9.0         0
#
#             package  retail_price
# 1               Box        199.99
# 2               Box        149.99
# 3               Box          9.99
# 4               Box         34.99
# 5               Box         49.99
# ...             ...           ...
# 12082  Blister pack          0.98
# 12083  Blister pack          0.98
# 12091           Box          0.50
# 12092    Wooden box        100.00
# 12106           Box          0.50
#
# [4360 rows x 10 columns]

# %%
lego2.loc[lego2.pieces == 0, :]
# syntax:
#lego2.loc[condition of row to be shown from col, :(meaning show all observations)]
#loc[] has 2 parameters: [row condition, columns]
lego2.loc[lego2.retail_price == 0, :]
# Out:
#              id                               name     themegroup  \
# 2266    40135-1                        Angler Fish  Miscellaneous
# 2269    40138-1                    Christmas Train  Miscellaneous
# 2882    40094-1                         Snowplough  Miscellaneous
# 2884    40096-1                        Spring Tree  Miscellaneous
# 2885    40097-1                         Helicopter  Miscellaneous
# ...         ...                                ...            ...
# 7435   LMG001-1                         Small Duck  Miscellaneous
# 7549     3929-1  Biff Starling Astrobot Minifigure  Miscellaneous
# 9100     2845-1                       Indian Chief     Historical
# 9101     2846-1                       Indian Kayak     Historical
# 9258  ORLANDO-1                    {Bag of Bricks}  Miscellaneous
#
#             theme                      subtheme    year  pieces  minifigs  \
# 2266  Promotional      Monthly Mini Model Build  2015.0    29.0         0
# 2269     Seasonal                     Christmas  2015.0   233.0         0
# 2882  Promotional      Monthly Mini Model Build  2014.0    46.0         0
# 2884  Promotional      Monthly Mini Model Build  2014.0    62.0         0
# 2885  Promotional      Monthly Mini Model Build  2014.0    44.0         0
# ...           ...                           ...     ...     ...       ...
# 7435  Promotional                 Miscellaneous  2003.0     8.0         0
# 7549  Promotional                    Minifigure  2002.0     5.0         1
# 9100      Western                       Indians  1997.0    20.0         1
# 9101      Western                       Indians  1997.0    18.0         1
# 9258  Promotional  LEGO brand store opening set  1997.0     3.0         0
#
#                  package  retail_price
# 2266             Polybag           0.0
# 2269                 Box           0.0
# 2882             Polybag           0.0
# 2884             Polybag           0.0
# 2885             Polybag           0.0
# ...                  ...           ...
# 7435  None (loose parts)           0.0
# 7549             Polybag           0.0
# 9100                 Box           0.0
# 9101                 Box           0.0
# 9258  None (loose parts)           0.0
#
# [83 rows x 10 columns]

# %% [markdown]
# #### Question 2:
# Arrange the dataset in descending order of retail_price and print the first three rows. Report in words the names of the three most expensive lego sets, their prices, and how many pieces each has.

# %%
# Write your answer here
lego2.sort_values(by='retail_price',ascending=False).head(3)
# sort_vaues has 2 attributes: by(where you specify the column), & ascending (where u specify the order)
# Out:
#            id                                    name themegroup      theme  \
# 1434  75192-1                       Millennium Falcon   Licensed  Star Wars
# 2065  75159-1                              Death Star   Licensed  Star Wars
# 5944  10179-1  Ultimate Collector's Millennium Falcon   Licensed  Star Wars
#
#                        subtheme    year  pieces  minifigs package  \
# 1434  Ultimate Collector Series  2017.0  7541.0         8     Box
# 2065  Ultimate Collector Series  2016.0  4016.0        27     Box
# 5944  Ultimate Collector Series  2007.0  5197.0         5     Box
#
#       retail_price
# 1434        799.99
# 2065        499.99
# 5944        499.99

# %% [markdown]
# #### Question 3:
#
# It appears that the most expensive sets generally have more pieces. Create a new variable (column) price_per_piece, representing the price in dollars per piece for each of the sets. Save the result as lego2. Hence, you will overwrite the current lego object.

# %%
# Write your answer here
lego2['price_per_piece'] = lego2.retail_price / lego2.pieces
lego2.sort_values(by='price_per_piece',ascending=False).head(3)
# Out:
# /var/folders/c9/4rn2mxxs6yl48gvc_hqwcjjh0000gn/T/ipykernel_92741/128972578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lego2['price_per_piece'] = lego2.retail_price / lego2.pieces
#                id                       name themegroup            theme  \
# 5551       8878-1   Rechargeable Battery Box  Technical  Power Functions
# 5553       8887-1         Transformer 10V DC  Technical  Power Functions
# 5616  COMCON005-1  Collectable Display Set 2   Licensed        Star Wars
#
#            subtheme    year  pieces  minifigs      package  retail_price  \
# 5551    Accessories  2009.0     1.0         0      Polybag         49.99
# 5553    Accessories  2009.0     1.0         0      Polybag         29.99
# 5616  Miscellaneous  2009.0     2.0         3  Plastic box         49.99
#
#       price_per_piece
# 5551           49.990
# 5553           29.990
# 5616           24.995

# %% [markdown]
# #### Question 4:
#
# Arrange the lego2 dataset in descending order of price_per_piece and return only the columns: name, themegroup, theme, pieces, price_per_piece, and the first five rows. What do you notice about these sets?

# %%
# Write your answer here
lego3=lego2.sort_values(by='price_per_piece', ascending=False)
lego3.loc[ :,'name''themegroup''theme''pieces''price_per_piece']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'namethemegroupthemepiecesprice_per_piece'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 3
#       1 # Write your answer here
#       2 lego3=lego2.sort_values(by='price_per_piece', ascending=False)
# ----> 3 lego3.loc[ :,'name''themegroup''theme''pieces''price_per_piece']
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1065, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061 for i, key in enumerate(tup):
#    1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
# -> 1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#    1070         if section.ndim == self.ndim:
#    1071             # we're in the middle of slicing through a MultiIndex
#    1072             # revise the key wrt to `section` by inserting an _NS
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:4287, in NDFrame.xs(self, key, axis, level, drop_level)
#    4285 if axis == 1:
#    4286     if drop_level:
# -> 4287         return self[key]
#    4288     index = self.columns
#    4289 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'namethemegroupthemepiecesprice_per_piece'

# %% [markdown]
# #### Question 5:
#
# What is the mean price_per_piece for the top 40 'Toy Story' sets in terms of price_per_piece?

# %%
# Write your answer here
lego3=lego2.sort_values(by='price_per_piece', ascending=False)
lego3.loc[lego3.theme=='Star Wars',:].head(40).price_per_piece.mean()
# mean of price per piece of only the first 40 observations
# Out:
# 2.036166411264348

# %% [markdown]
# #### Question 6:
#
# What are the unique themes in the lego dataset?

# %%
# Write your answer here
lego2.theme.value_counts()
# Out:
# theme
# Star Wars                            503
# Collectable Minifigures              431
# City                                 391
# Town                                 310
# Racers                               183
#                                     ...
# The Lego Movie 2: The Second Part      2
# Explore                                1
# Bricks and More                        1
# Books                                  1
# LEGOLAND                               1
# Name: count, Length: 73, dtype: int64
